# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.7/dist-packages (2.1.2)

# %%
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
import random
import pygame, sys
from collections import deque
from IPython.display import clear_output
import time
from pygame.locals import *
from random import randint
from random import choice

# %%
class Paddle:
    def __init__(self, x, y, l, w, s, n):
        self.ypos = y
        self.xpos = x
        self.length = l
        self.width = w
        self.speed = s
        self.number = n

    def move(self, ypos, action, playernumber):
        if playernumber == 1:
            if action[pygame.K_UP]:
                if(ypos-self.speed < -60):
                    self.ypos = -60
                else:
                    self.ypos -= self.speed
            if action[pygame.K_DOWN]:
                if(ypos+self.length+self.speed > 780):
                    self.ypos = 780-self.length
                else:
                    self.ypos += self.speed

        if playernumber == 2:
            if action == 0:
                self.ypos -= self.speed
                if (self.ypos < 0):
                    self.ypos = 0
            if action == 1:
                self.ypos += self.speed
                if(self.ypos > 720):
                    self.ypos = 720

    def continuepos(self):
        return int(self.ypos)

# %%
class SimpleBall:
    def __init__(self, x, y, xspeed, yspeed, speed_rate, size):
        self.xspeed = xspeed
        self.yspeed = yspeed
        self.xpos = x
        self.ypos = y
        self.size = size
        self.speed_rate = speed_rate

    def move(self, paddle1, paddle2):

        hit = 0 

        if(self.ypos + self.yspeed < 0):
            self.ypos = 0
            self.yspeed = -self.yspeed
            
        elif(self.ypos + self.yspeed > 720):
            self.ypos = 720
            self.yspeed = -self.yspeed

        else:
            self.ypos += self.yspeed

        if(self.xpos < self.size and ((paddle1.ypos - self.size <= self.ypos) and (self.ypos <= (paddle1.ypos + paddle1.length)))):
            self.xspeed -= self.speed_rate
            self.xspeed = -self.xspeed
            self.xpos = self.size

            if (self.yspeed > 0):
                self.yspeed += self.speed_rate
            else:
                self.yspeed -= self.speed_rate

            hit = 1
        
        elif(self.xpos > 740 and ((paddle2.ypos - self.size <= self.ypos) and (self.ypos <= (paddle2.ypos + paddle2.length)))):

            self.xspeed += self.speed_rate
            self.xspeed = -self.xspeed
            self.xpos = 740

            if (self.yspeed > 0):
                self.yspeed += self.speed_rate
            else:
                self.yspeed -= self.speed_rate
            
            hit = 1
        else:
            self.xpos += self.xspeed

        return hit
    
    def continuepos (self):
        return self.xpos,self.ypos
    
    def continuevel (self):
        return self.xspeed, self.yspeed

# %%
class DiscretePongMDP():
    def __init__(self, scale):
        
        self.scale = scale

        self.paddle1 = Paddle(740, 300, 120, 20, 2*self.scale, 2)
        self.paddle2 = Paddle(20, 300, 120, 20, 2*self.scale, 2)

        self.pongball = SimpleBall(780/2, 720/2 , choice([-1,1]) * 2 *self.scale, choice([-1,1]) * 2 * self.scale, 0.5*self.scale, 20)


    def update(self, a):
    
        running = True
        r = 0
        hit = 0

        self.paddle2.move(self.paddle2.ypos, a, self.paddle2.number)
       
        if (self.paddle1.ypos + 60 > self.pongball.ypos):
            a = 0
        else:
            a = 1
        self.paddle1.move(self.paddle1.ypos, a, self.paddle1.number)

        hit = self.pongball.move(self.paddle2, self.paddle1)

        if (self.pongball.xpos < 0):
            r = -100
            running = False

        if (self.pongball.xpos > 780):
            r = 100
            running = False

        xv, yv = self.pongball.continuevel()
        x, y = self.pongball.continuepos()
        p = self.paddle2.continuepos()

        return (p, x, y, xv, yv), r, running, hit

# %%
class DQNAgent:
    def __init__(self, stateSpaceSize, actionSpace):

        self.actionSpace = actionSpace

        self.gamma = 0.99

        self.syncModelsepisodes = 5

        self.model = self.createDqnModel(stateSpaceSize, actionSpace)

        self.targetModel = self.createDqnModel(stateSpaceSize, actionSpace)

        self.memory = []
        self.batchSize = 32

    def createDqnModel(self, stateSpaceSize, actionSpace):
        inputs = Input(shape=(stateSpaceSize, ))
        x = Dense(128, activation='relu')(inputs)
        x = Dense(128, activation='relu')(x)
        x = Dense(64, activation='relu')(x)
        x = Dense(len(actionSpace), activation='linear')(x)
        model = Model(inputs, x)
        model.summary()
        model.compile(loss='mse', optimizer='adam')

        return model

    def act(self, state, epsilon):
        if np.random.rand() > epsilon:
            normalState = self.prepState(state)
            qValues = self.model.predict(normalState)
            return np.argmax(qValues[0])
        else:
            return random.choice(self.actionSpace)

    def calcTarget(self, nextState, reward):
        nestNormalState = self.prepState(nextState)
        maxQValue = np.max(self.targetModel.predict(nestNormalState))
        targetQVal = reward + self.gamma * maxQValue
        return targetQVal

    def remember(self, state, action, reward, nextState, done):
        item = (state, action, reward, nextState, done)
        if len(self.memory) > 10000:
            self.memory.pop(0)
        self.memory.append(item)
        
    def prepState(self, state):
        return np.expand_dims(np.asarray([state[0]/720, state[1]/780, state[2]/720, state[3]/10, state[4]/10]), axis=0)

    def replay(self):
        batch = random.sample(self.memory, self.batchSize)
        xTrain, yTrain = [], []

        for state, action, reward, nextState, done in batch:
            normalState = self.prepState(state)
            qValues = self.model.predict(normalState)
            
            targetQVal = self.calcTarget(nextState, reward)

            qValues[0][action] = reward if done else targetQVal

            xTrain.append(normalState[0])
            yTrain.append(qValues[0])

        self.model.fit(np.array(xTrain),
                         np.array(yTrain),
                         batch_size=self.batchSize,
                         epochs=1,
                         verbose=0)

    def syncModels(self):
        self.targetModel.set_weights(self.model.get_weights()) 

def getLearningRate(episode):
    return np.max([0.8 * np.power(0.9992, episode), 0.02])

def getExplorationRate(episode):
    return np.max([1 * np.power(0.9995, episode), 0.02])

# %%
NumEpisodes = 5000
MaxTimeSteps = 50000
tracker = np.zeros((int(NumEpisodes/100)+1,2))

tf.compat.v1.disable_eager_execution()

agent = DQNAgent(5, [0, 1])

NumEpisodes = 5000
tracker = np.zeros((int(NumEpisodes/100)+1,2))

trainInterval = 10

gameStep = 0

plotScores = []

sumScores = 0
avgScores = []

for episode in range(NumEpisodes):
    scores = [0, 0]
    while True:
        MDP = DiscretePongMDP(scale=10)
        s, r, running, temp = MDP.update(2)
        explorationRate = getExplorationRate(episode)
        running = True
        while(running):
            a = agent.act(s, explorationRate)
            ns, r, running, hit = MDP.update(a)
            agent.remember(s, a, r, ns, not running)

            s = ns
            if r == 100:
                scores[1] += 1
            elif r == -100:
                scores[0] += 1
            
            if len(agent.memory) > 1e2 and gameStep % 50 == 0:
                agent.replay()

            gameStep += 1

        if scores[0] == 21 or scores[1] == 21:
            break

    sumScores += scores[1] - scores[0]
    avgScores.append(sumScores / (episode + 1))

    if episode % agent.syncModelsepisodes == 0:
        agent.syncModels()


    print('Episode {} result: {} - {} , epsilon: {}'.format(episode, scores[0], scores[1], explorationRate))

sns.set_style("darkgrid")

plt.figure()
df = pd.DataFrame({'Avg Scores': avgScores, 'Episodes': range(NumEpisodes)})

ax = sns.lineplot(x="Episodes", y="Avg Scores", data=df).set_title("Deep-Q Learning Agent")

plt.show()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 5)]               0
#
#  dense_32 (Dense)            (None, 128)               768
#
#  dense_33 (Dense)            (None, 128)               16512
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  dense_35 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 25,666
# Trainable params: 25,666
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 5)]               0
#
#  dense_36 (Dense)            (None, 128)               768
#
#  dense_37 (Dense)            (None, 128)               16512
#
#  dense_38 (Dense)            (None, 64)                8256
#
#  dense_39 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 25,666
# Trainable params: 25,666
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-07 19:08:59.144888: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:08:59.163301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:08:59.206094: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:08:59.236976: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:08:59.434805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:08:59.456286: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:08:59.470022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:09:01.123486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-07 19:09:01.146721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Episode 0 result: 21 - 3 , epsilon: 1.0
# Average Reward	 -1.9758507135016465
# Episode 1 result: 21 - 1 , epsilon: 0.9995
# Average Reward	 -2.7
# Episode 2 result: 21 - 0 , epsilon: 0.9990002500000001
# Average Reward	 -3.2
# Episode 3 result: 21 - 0 , epsilon: 0.9985007498750001
# Average Reward	 -3.3
# Episode 4 result: 21 - 1 , epsilon: 0.9980014995000627
# Average Reward	 -2.5
# Episode 5 result: 21 - 0 , epsilon: 0.9975024987503127
# Average Reward	 -2.4
# Episode 6 result: 21 - 0 , epsilon: 0.9970037475009377
# Average Reward	 -2.9
# Episode 7 result: 21 - 0 , epsilon: 0.9965052456271872
# Average Reward	 -3.0
# Episode 8 result: 21 - 0 , epsilon: 0.9960069930043737
# Average Reward	 -3.3
# Episode 9 result: 21 - 1 , epsilon: 0.9955089895078716
# Average Reward	 -3.0
# Episode 10 result: 21 - 0 , epsilon: 0.9950112350131177
# Average Reward	 -3.0
# Episode 11 result: 21 - 0 , epsilon: 0.9945137293956112
# Average Reward	 -2.8
# Episode 12 result: 21 - 1 , epsilon: 0.9940164725309134
# Average Reward	 -2.8
# Episode 13 result: 21 - 1 , epsilon: 0.993519464294648
# Average Reward	 -2.8
# Episode 14 result: 21 - 0 , epsilon: 0.9930227045625007
# Average Reward	 -3.2
# Episode 15 result: 21 - 0 , epsilon: 0.9925261932102195
# Average Reward	 -2.9
# Episode 16 result: 21 - 1 , epsilon: 0.9920299301136145
# Average Reward	 -2.6
# Episode 17 result: 21 - 0 , epsilon: 0.9915339151485577
# Average Reward	 -2.8
# Episode 18 result: 21 - 0 , epsilon: 0.9910381481909836
# Average Reward	 -3.0
# Episode 19 result: 21 - 0 , epsilon: 0.9905426291168881
# Average Reward	 -2.9
# Episode 20 result: 21 - 2 , epsilon: 0.9900473578023297
# Average Reward	 -2.5
# Episode 21 result: 21 - 0 , epsilon: 0.9895523341234286
# Average Reward	 -2.5
# Episode 22 result: 21 - 0 , epsilon: 0.989057557956367
# Average Reward	 -2.9
# Episode 23 result: 21 - 0 , epsilon: 0.9885630291773888
# Average Reward	 -2.9
# Episode 24 result: 21 - 1 , epsilon: 0.9880687476628002
# Average Reward	 -2.7
# Episode 25 result: 21 - 1 , epsilon: 0.9875747132889688
# Average Reward	 -2.5
# Episode 26 result: 21 - 0 , epsilon: 0.9870809259323243
# Average Reward	 -2.6
# Episode 27 result: 21 - 0 , epsilon: 0.9865873854693583
# Average Reward	 -3.1
# Episode 28 result: 21 - 0 , epsilon: 0.9860940917766237
# Average Reward	 -3.2
# Episode 29 result: 21 - 0 , epsilon: 0.9856010447307354
# Average Reward	 -3.0
# Episode 30 result: 21 - 0 , epsilon: 0.9851082442083701
# Average Reward	 -3.2
# Episode 31 result: 21 - 0 , epsilon: 0.9846156900862659
# Average Reward	 -3.5
# Episode 32 result: 21 - 1 , epsilon: 0.9841233822412229
# Average Reward	 -2.5
# Episode 33 result: 21 - 0 , epsilon: 0.9836313205501023
# Average Reward	 -3.0
# Episode 34 result: 21 - 0 , epsilon: 0.9831395048898273
# Average Reward	 -2.7
# Episode 35 result: 21 - 0 , epsilon: 0.9826479351373825
# Average Reward	 -3.1
# Episode 36 result: 21 - 1 , epsilon: 0.9821566111698138
# Average Reward	 -2.7
# Episode 37 result: 21 - 0 , epsilon: 0.981665532864229
# Average Reward	 -3.2
# Episode 38 result: 21 - 0 , epsilon: 0.981174700097797
# Average Reward	 -2.9
# Episode 39 result: 21 - 0 , epsilon: 0.980684112747748
# Average Reward	 -2.8
# Episode 40 result: 21 - 1 , epsilon: 0.9801937706913743
# Average Reward	 -2.5
# Episode 41 result: 21 - 1 , epsilon: 0.9797036738060286
# Average Reward	 -2.7
# Episode 42 result: 21 - 0 , epsilon: 0.9792138219691257
# Average Reward	 -3.3
# Episode 43 result: 21 - 0 , epsilon: 0.9787242150581411
# Average Reward	 -3.4
# Episode 44 result: 21 - 0 , epsilon: 0.9782348529506121
# Average Reward	 -3.2
# Episode 45 result: 21 - 0 , epsilon: 0.9777457355241369
# Average Reward	 -3.1
# Episode 46 result: 21 - 0 , epsilon: 0.9772568626563749
# Average Reward	 -3.0
# Episode 47 result: 21 - 0 , epsilon: 0.9767682342250468
# Average Reward	 -2.9
# Episode 48 result: 21 - 0 , epsilon: 0.9762798501079343
# Average Reward	 -2.9
# Episode 49 result: 21 - 0 , epsilon: 0.9757917101828804
# Average Reward	 -2.8
# Episode 50 result: 21 - 0 , epsilon: 0.9753038143277889
# Average Reward	 -2.6
# Episode 51 result: 21 - 0 , epsilon: 0.9748161624206251
# Average Reward	 -2.5
# Episode 52 result: 21 - 1 , epsilon: 0.9743287543394149
# Average Reward	 -2.8
# Episode 53 result: 21 - 0 , epsilon: 0.9738415899622452
# Average Reward	 -2.9
# Episode 54 result: 21 - 0 , epsilon: 0.9733546691672641
# Average Reward	 -2.9
# Episode 55 result: 21 - 0 , epsilon: 0.9728679918326806
# Average Reward	 -2.9
# Episode 56 result: 21 - 0 , epsilon: 0.9723815578367643
# Average Reward	 -3.2
# Episode 57 result: 21 - 1 , epsilon: 0.971895367057846
# Average Reward	 -2.7
# Episode 58 result: 21 - 0 , epsilon: 0.971409419374317
# Average Reward	 -3.2
# Episode 59 result: 21 - 1 , epsilon: 0.97092371466463
# Average Reward	 -3.3
# Episode 60 result: 21 - 1 , epsilon: 0.9704382528072977
# Average Reward	 -2.5
# Episode 61 result: 21 - 1 , epsilon: 0.9699530336808941
# Average Reward	 -2.5
# Episode 62 result: 21 - 0 , epsilon: 0.9694680571640537
# Average Reward	 -3.5
# Episode 63 result: 21 - 0 , epsilon: 0.9689833231354718
# Average Reward	 -2.6
# Episode 64 result: 21 - 0 , epsilon: 0.968498831473904
# Average Reward	 -2.7
# Episode 65 result: 21 - 0 , epsilon: 0.9680145820581672
# Average Reward	 -2.9
# Episode 66 result: 21 - 0 , epsilon: 0.9675305747671381
# Average Reward	 -2.7
# Episode 67 result: 21 - 0 , epsilon: 0.9670468094797546
# Average Reward	 -2.9
# Episode 68 result: 21 - 0 , epsilon: 0.9665632860750147
# Average Reward	 -2.6
# Episode 69 result: 21 - 0 , epsilon: 0.9660800044319773
# Average Reward	 -3.1
# Episode 70 result: 21 - 1 , epsilon: 0.9655969644297614
# Average Reward	 -3.1
# Episode 71 result: 21 - 0 , epsilon: 0.9651141659475466
# Average Reward	 -2.6
# Episode 72 result: 21 - 2 , epsilon: 0.9646316088645729
# Average Reward	 -2.6
# Episode 73 result: 21 - 0 , epsilon: 0.9641492930601406
# Average Reward	 -3.0
# Episode 74 result: 21 - 0 , epsilon: 0.9636672184136106
# Average Reward	 -3.0
# Episode 75 result: 21 - 1 , epsilon: 0.9631853848044039
# Average Reward	 -2.8
# Episode 76 result: 21 - 0 , epsilon: 0.9627037921120017
# Average Reward	 -2.5
# Episode 77 result: 21 - 0 , epsilon: 0.9622224402159457
# Average Reward	 -2.7
# Episode 78 result: 21 - 0 , epsilon: 0.9617413289958379
# Average Reward	 -3.2
# Episode 79 result: 21 - 1 , epsilon: 0.96126045833134
# Average Reward	 -2.5
# Episode 80 result: 21 - 1 , epsilon: 0.9607798281021743
# Average Reward	 -2.2
# Episode 81 result: 21 - 0 , epsilon: 0.9602994381881234
# Average Reward	 -2.6
# Episode 82 result: 21 - 0 , epsilon: 0.9598192884690293
# Average Reward	 -3.0
# Episode 83 result: 21 - 1 , epsilon: 0.9593393788247948
# Average Reward	 -2.6
# Episode 84 result: 21 - 0 , epsilon: 0.9588597091353825
# Average Reward	 -2.6
# Episode 85 result: 21 - 0 , epsilon: 0.9583802792808148
# Average Reward	 -2.4
# Episode 86 result: 21 - 0 , epsilon: 0.9579010891411746
# Average Reward	 -3.0
# Episode 87 result: 21 - 0 , epsilon: 0.957422138596604
# Average Reward	 -2.9
# Episode 88 result: 21 - 0 , epsilon: 0.9569434275273058
# Average Reward	 -2.9
# Episode 89 result: 21 - 0 , epsilon: 0.9564649558135421
# Average Reward	 -3.0
# Episode 90 result: 21 - 0 , epsilon: 0.9559867233356354
# Average Reward	 -3.5
# Episode 91 result: 21 - 0 , epsilon: 0.9555087299739676
# Average Reward	 -3.2
# Episode 92 result: 21 - 1 , epsilon: 0.9550309756089808
# Average Reward	 -2.7
# Episode 93 result: 21 - 1 , epsilon: 0.9545534601211763
# Average Reward	 -3.0
# Episode 94 result: 21 - 0 , epsilon: 0.9540761833911158
# Average Reward	 -3.1
# Episode 95 result: 21 - 0 , epsilon: 0.9535991452994202
# Average Reward	 -2.9
# Episode 96 result: 21 - 0 , epsilon: 0.9531223457267706
# Average Reward	 -2.9
# Episode 97 result: 21 - 1 , epsilon: 0.9526457845539072
# Average Reward	 -3.0
# Episode 98 result: 21 - 0 , epsilon: 0.9521694616616303
# Average Reward	 -2.2
# Episode 99 result: 21 - 0 , epsilon: 0.9516933769307996
# Average Reward	 -2.9
# Episode 100 result: 21 - 0 , epsilon: 0.9512175302423342
# Average Reward	 -2.7
# Episode 101 result: 21 - 3 , epsilon: 0.9507419214772131
# Average Reward	 -1.8
# Episode 102 result: 21 - 2 , epsilon: 0.9502665505164746
# Average Reward	 -2.1
# Episode 103 result: 21 - 0 , epsilon: 0.9497914172412164
# Average Reward	 -2.3
# Episode 104 result: 21 - 1 , epsilon: 0.9493165215325958
# Average Reward	 -2.6
# Episode 105 result: 21 - 0 , epsilon: 0.9488418632718296
# Average Reward	 -3.2
# Episode 106 result: 21 - 0 , epsilon: 0.9483674423401937
# Average Reward	 -3.3
# Episode 107 result: 21 - 1 , epsilon: 0.9478932586190236
# Average Reward	 -3.0
# Episode 108 result: 21 - 1 , epsilon: 0.9474193119897142
# Average Reward	 -2.8
# Episode 109 result: 21 - 0 , epsilon: 0.9469456023337194
# Average Reward	 -2.8
# Episode 110 result: 21 - 0 , epsilon: 0.9464721295325526
# Average Reward	 -3.3
# Episode 111 result: 21 - 0 , epsilon: 0.9459988934677863
# Average Reward	 -2.9
# Episode 112 result: 21 - 2 , epsilon: 0.9455258940210525
# Average Reward	 -2.3
# Episode 113 result: 21 - 0 , epsilon: 0.9450531310740421
# Average Reward	 -2.7
# Episode 114 result: 21 - 1 , epsilon: 0.9445806045085051
# Average Reward	 -2.6
# Episode 115 result: 21 - 1 , epsilon: 0.9441083142062509
# Average Reward	 -2.5
# Episode 116 result: 21 - 0 , epsilon: 0.9436362600491478
# Average Reward	 -3.0
# Episode 117 result: 21 - 0 , epsilon: 0.9431644419191233
# Average Reward	 -3.5
# Episode 118 result: 21 - 1 , epsilon: 0.9426928596981637
# Average Reward	 -2.7
# Episode 119 result: 21 - 1 , epsilon: 0.9422215132683147
# Average Reward	 -2.9
# Episode 120 result: 21 - 0 , epsilon: 0.9417504025116806
# Average Reward	 -2.8
# Episode 121 result: 21 - 0 , epsilon: 0.9412795273104249
# Average Reward	 -2.6
# Episode 122 result: 21 - 1 , epsilon: 0.9408088875467697
# Average Reward	 -2.4
# Episode 123 result: 21 - 0 , epsilon: 0.9403384831029964
# Average Reward	 -2.7
# Episode 124 result: 21 - 0 , epsilon: 0.9398683138614449
# Average Reward	 -3.0
# Episode 125 result: 21 - 0 , epsilon: 0.9393983797045142
# Average Reward	 -2.8
# Episode 126 result: 21 - 0 , epsilon: 0.938928680514662
# Average Reward	 -2.8
# Episode 127 result: 21 - 0 , epsilon: 0.9384592161744048
# Average Reward	 -3.0
# Episode 128 result: 21 - 0 , epsilon: 0.9379899865663176
# Average Reward	 -2.9
# Episode 129 result: 21 - 0 , epsilon: 0.9375209915730345
# Average Reward	 -2.7
# Episode 130 result: 21 - 0 , epsilon: 0.937052231077248
# Average Reward	 -3.0
# Episode 131 result: 21 - 0 , epsilon: 0.9365837049617095
# Average Reward	 -3.0
# Episode 132 result: 21 - 1 , epsilon: 0.9361154131092286
# Average Reward	 -2.7
# Episode 133 result: 21 - 0 , epsilon: 0.9356473554026741
# Average Reward	 -3.0
# Episode 134 result: 21 - 1 , epsilon: 0.9351795317249728
# Average Reward	 -2.9
# Episode 135 result: 21 - 0 , epsilon: 0.9347119419591103
# Average Reward	 -2.7
# Episode 136 result: 21 - 0 , epsilon: 0.9342445859881309
# Average Reward	 -3.1
# Episode 137 result: 21 - 1 , epsilon: 0.9337774636951368
# Average Reward	 -2.8
# Episode 138 result: 21 - 1 , epsilon: 0.9333105749632893
# Average Reward	 -2.4
# Episode 139 result: 21 - 0 , epsilon: 0.9328439196758077
# Average Reward	 -2.6
# Episode 140 result: 21 - 1 , epsilon: 0.9323774977159699
# Average Reward	 -2.8
# Episode 141 result: 21 - 0 , epsilon: 0.9319113089671119
# Average Reward	 -3.0
# Episode 142 result: 21 - 0 , epsilon: 0.9314453533126285
# Average Reward	 -2.9
# Episode 143 result: 21 - 0 , epsilon: 0.9309796306359722
# Average Reward	 -2.6
# Episode 144 result: 21 - 0 , epsilon: 0.9305141408206543
# Average Reward	 -2.7
# Episode 145 result: 21 - 0 , epsilon: 0.930048883750244
# Average Reward	 -3.2
# Episode 146 result: 21 - 0 , epsilon: 0.929583859308369
# Average Reward	 -3.0
# Episode 147 result: 21 - 0 , epsilon: 0.9291190673787147
# Average Reward	 -3.0
# Episode 148 result: 21 - 0 , epsilon: 0.9286545078450255
# Average Reward	 -3.1
# Episode 149 result: 21 - 0 , epsilon: 0.928190180591103
# Average Reward	 -2.5
# Episode 150 result: 21 - 0 , epsilon: 0.9277260855008075
# Average Reward	 -3.0
# Episode 151 result: 21 - 0 , epsilon: 0.9272622224580571
# Average Reward	 -3.3
# Episode 152 result: 21 - 1 , epsilon: 0.9267985913468282
# Average Reward	 -2.7
# Episode 153 result: 21 - 0 , epsilon: 0.9263351920511548
# Average Reward	 -2.8
# Episode 154 result: 21 - 2 , epsilon: 0.9258720244551293
# Average Reward	 -2.5
# Episode 155 result: 21 - 0 , epsilon: 0.9254090884429018
# Average Reward	 -2.8
# Episode 156 result: 21 - 0 , epsilon: 0.9249463838986803
# Average Reward	 -3.2
# Episode 157 result: 21 - 1 , epsilon: 0.9244839107067311
# Average Reward	 -3.0
# Episode 158 result: 21 - 0 , epsilon: 0.9240216687513778
# Average Reward	 -3.6
# Episode 159 result: 21 - 0 , epsilon: 0.9235596579170021
# Average Reward	 -3.6
# Episode 160 result: 21 - 0 , epsilon: 0.9230978780880437
# Average Reward	 -2.7
# Episode 161 result: 21 - 0 , epsilon: 0.9226363291489997
# Average Reward	 -3.2
# Episode 162 result: 21 - 0 , epsilon: 0.9221750109844252
# Average Reward	 -2.9
# Episode 163 result: 21 - 1 , epsilon: 0.9217139234789331
# Average Reward	 -2.5
# Episode 164 result: 21 - 0 , epsilon: 0.9212530665171936
# Average Reward	 -2.8
# Episode 165 result: 21 - 0 , epsilon: 0.9207924399839351
# Average Reward	 -2.7
# Episode 166 result: 21 - 0 , epsilon: 0.9203320437639432
# Average Reward	 -2.6
# Episode 167 result: 21 - 0 , epsilon: 0.9198718777420613
# Average Reward	 -2.6
# Episode 168 result: 21 - 0 , epsilon: 0.9194119418031903
# Average Reward	 -2.9
# Episode 169 result: 21 - 0 , epsilon: 0.9189522358322888
# Average Reward	 -3.1
# Episode 170 result: 21 - 0 , epsilon: 0.9184927597143727
# Average Reward	 -2.9
# Episode 171 result: 21 - 0 , epsilon: 0.9180335133345155
# Average Reward	 -2.8
# Episode 172 result: 21 - 1 , epsilon: 0.9175744965778483
# Average Reward	 -2.6
# Episode 173 result: 21 - 0 , epsilon: 0.9171157093295594
# Average Reward	 -3.0
# Episode 174 result: 21 - 0 , epsilon: 0.9166571514748947
# Average Reward	 -3.3
# Episode 175 result: 21 - 1 , epsilon: 0.9161988228991573
# Average Reward	 -2.5
# Episode 176 result: 21 - 1 , epsilon: 0.9157407234877079
# Average Reward	 -2.0
# Episode 177 result: 21 - 0 , epsilon: 0.915282853125964
# Average Reward	 -2.6
# Episode 178 result: 21 - 0 , epsilon: 0.9148252116994011
# Average Reward	 -2.9
# Episode 179 result: 21 - 1 , epsilon: 0.9143677990935515
# Average Reward	 -2.5
# Episode 180 result: 21 - 1 , epsilon: 0.9139106151940047
# Average Reward	 -2.8
# Episode 181 result: 21 - 0 , epsilon: 0.9134536598864077
# Average Reward	 -3.0
# Episode 182 result: 21 - 0 , epsilon: 0.9129969330564646
# Average Reward	 -3.3
# Episode 183 result: 21 - 0 , epsilon: 0.9125404345899364
# Average Reward	 -3.3
# Episode 184 result: 21 - 0 , epsilon: 0.9120841643726415
# Average Reward	 -2.6
# Episode 185 result: 21 - 0 , epsilon: 0.9116281222904552
# Average Reward	 -3.0
# Episode 186 result: 21 - 0 , epsilon: 0.9111723082293101
# Average Reward	 -2.9
# Episode 187 result: 21 - 0 , epsilon: 0.9107167220751955
# Average Reward	 -2.6
# Episode 188 result: 21 - 2 , epsilon: 0.9102613637141579
# Average Reward	 -2.3
# Episode 189 result: 21 - 0 , epsilon: 0.9098062330323009
# Average Reward	 -2.7
# Episode 190 result: 21 - 1 , epsilon: 0.9093513299157847
# Average Reward	 -2.9
# Episode 191 result: 21 - 0 , epsilon: 0.9088966542508269
# Average Reward	 -3.0
# Episode 192 result: 21 - 0 , epsilon: 0.9084422059237015
# Average Reward	 -2.9
# Episode 193 result: 21 - 0 , epsilon: 0.9079879848207397
# Average Reward	 -2.8
# Episode 194 result: 21 - 0 , epsilon: 0.9075339908283294
# Average Reward	 -3.0
# Episode 195 result: 21 - 1 , epsilon: 0.9070802238329153
# Average Reward	 -3.0
# Episode 196 result: 21 - 0 , epsilon: 0.906626683720999
# Average Reward	 -2.9
# Episode 197 result: 21 - 0 , epsilon: 0.9061733703791385
# Average Reward	 -3.3
# Episode 198 result: 21 - 0 , epsilon: 0.905720283693949
# Average Reward	 -2.7
# Episode 199 result: 21 - 0 , epsilon: 0.905267423552102
# Average Reward	 -2.8
# Episode 200 result: 21 - 1 , epsilon: 0.904814789840326
# Average Reward	 -2.8
# Episode 201 result: 21 - 0 , epsilon: 0.9043623824454059
# Average Reward	 -2.7
# Episode 202 result: 21 - 0 , epsilon: 0.9039102012541833
# Average Reward	 -3.0
# Episode 203 result: 21 - 0 , epsilon: 0.9034582461535562
# Average Reward	 -2.9
# Episode 204 result: 21 - 0 , epsilon: 0.9030065170304795
# Average Reward	 -3.0
# Episode 205 result: 21 - 0 , epsilon: 0.9025550137719643
# Average Reward	 -3.2
# Episode 206 result: 21 - 0 , epsilon: 0.9021037362650783
# Average Reward	 -3.3
# Episode 207 result: 21 - 1 , epsilon: 0.9016526843969459
# Average Reward	 -2.8
# Episode 208 result: 21 - 1 , epsilon: 0.9012018580547474
# Average Reward	 -2.8
# Episode 209 result: 21 - 0 , epsilon: 0.9007512571257201
# Average Reward	 -3.0
# Episode 210 result: 21 - 0 , epsilon: 0.9003008814971574
# Average Reward	 -3.2
# Episode 211 result: 21 - 2 , epsilon: 0.8998507310564088
# Average Reward	 -2.0
# Episode 212 result: 21 - 1 , epsilon: 0.8994008056908807
# Average Reward	 -2.5
# Episode 213 result: 21 - 1 , epsilon: 0.8989511052880352
# Average Reward	 -2.9
# Episode 214 result: 21 - 0 , epsilon: 0.8985016297353913
# Average Reward	 -3.0
# Episode 215 result: 21 - 0 , epsilon: 0.8980523789205236
# Average Reward	 -2.7
# Episode 216 result: 21 - 1 , epsilon: 0.8976033527310634
# Average Reward	 -2.5
# Episode 217 result: 21 - 0 , epsilon: 0.8971545510546979
# Average Reward	 -2.9
# Episode 218 result: 21 - 1 , epsilon: 0.8967059737791706
# Average Reward	 -2.9
# Episode 219 result: 21 - 0 , epsilon: 0.8962576207922811
# Average Reward	 -3.5
# Episode 220 result: 21 - 1 , epsilon: 0.895809491981885
# Average Reward	 -3.1
# Episode 221 result: 21 - 0 , epsilon: 0.8953615872358941
# Average Reward	 -2.9
# Episode 222 result: 21 - 1 , epsilon: 0.8949139064422762
# Average Reward	 -2.8
# Episode 223 result: 21 - 0 , epsilon: 0.8944664494890552
# Average Reward	 -2.6
# Episode 224 result: 21 - 0 , epsilon: 0.8940192162643107
# Average Reward	 -3.5
# Episode 225 result: 21 - 0 , epsilon: 0.8935722066561785
# Average Reward	 -3.3
# Episode 226 result: 21 - 0 , epsilon: 0.8931254205528505
# Average Reward	 -2.8
# Episode 227 result: 21 - 0 , epsilon: 0.8926788578425742
# Average Reward	 -3.4
# Episode 228 result: 21 - 1 , epsilon: 0.8922325184136529
# Average Reward	 -3.0
# Episode 229 result: 21 - 0 , epsilon: 0.8917864021544462
# Average Reward	 -3.0
# Episode 230 result: 21 - 0 , epsilon: 0.8913405089533689
# Average Reward	 -2.9
# Episode 231 result: 21 - 0 , epsilon: 0.8908948386988923
# Average Reward	 -2.9
# Episode 232 result: 21 - 0 , epsilon: 0.8904493912795429
# Average Reward	 -3.1
# Episode 233 result: 21 - 0 , epsilon: 0.8900041665839031
# Average Reward	 -3.2
# Episode 234 result: 21 - 1 , epsilon: 0.8895591645006112
# Average Reward	 -3.1
# Episode 235 result: 21 - 2 , epsilon: 0.889114384918361
# Average Reward	 -2.3
# Episode 236 result: 21 - 0 , epsilon: 0.8886698277259019
# Average Reward	 -3.1
# Episode 237 result: 21 - 0 , epsilon: 0.888225492812039
# Average Reward	 -3.0
# Episode 238 result: 21 - 1 , epsilon: 0.887781380065633
# Average Reward	 -2.7
# Episode 239 result: 21 - 1 , epsilon: 0.8873374893756002
# Average Reward	 -2.8
# Episode 240 result: 21 - 0 , epsilon: 0.8868938206309125
# Average Reward	 -2.8
# Episode 241 result: 21 - 1 , epsilon: 0.8864503737205971
# Average Reward	 -2.6
# Episode 242 result: 21 - 0 , epsilon: 0.8860071485337369
# Average Reward	 -3.0
# Episode 243 result: 21 - 1 , epsilon: 0.88556414495947
# Average Reward	 -2.8
# Episode 244 result: 21 - 0 , epsilon: 0.8851213628869903
# Average Reward	 -2.7
# Episode 245 result: 21 - 2 , epsilon: 0.8846788022055468
# Average Reward	 -2.5
# Episode 246 result: 21 - 1 , epsilon: 0.8842364628044441
# Average Reward	 -2.3
# Episode 247 result: 21 - 1 , epsilon: 0.883794344573042
# Average Reward	 -2.8
# Episode 248 result: 21 - 2 , epsilon: 0.8833524474007555
# Average Reward	 -2.6
# Episode 249 result: 21 - 0 , epsilon: 0.8829107711770552
# Average Reward	 -2.8
# Episode 250 result: 21 - 0 , epsilon: 0.8824693157914667
# Average Reward	 -3.3
# Episode 251 result: 21 - 1 , epsilon: 0.882028081133571
# Average Reward	 -2.8
# Episode 252 result: 21 - 1 , epsilon: 0.8815870670930043
# Average Reward	 -2.7
# Episode 253 result: 21 - 1 , epsilon: 0.8811462735594578
# Average Reward	 -2.8
# Episode 254 result: 21 - 0 , epsilon: 0.8807057004226782
# Average Reward	 -2.8
# Episode 255 result: 21 - 1 , epsilon: 0.8802653475724669
# Average Reward	 -2.5
# Episode 256 result: 21 - 3 , epsilon: 0.8798252148986807
# Average Reward	 -2.0
# Episode 257 result: 21 - 0 , epsilon: 0.8793853022912314
# Average Reward	 -3.0
# Episode 258 result: 21 - 1 , epsilon: 0.8789456096400858
# Average Reward	 -2.5
# Episode 259 result: 21 - 1 , epsilon: 0.8785061368352658
# Average Reward	 -2.7
# Episode 260 result: 21 - 0 , epsilon: 0.8780668837668483
# Average Reward	 -2.7
# Episode 261 result: 21 - 0 , epsilon: 0.8776278503249648
# Average Reward	 -3.0
# Episode 262 result: 21 - 1 , epsilon: 0.8771890363998024
# Average Reward	 -3.0
# Episode 263 result: 21 - 0 , epsilon: 0.8767504418816026
# Average Reward	 -2.8
# Episode 264 result: 21 - 0 , epsilon: 0.8763120666606619
# Average Reward	 -3.3
# Episode 265 result: 21 - 1 , epsilon: 0.8758739106273316
# Average Reward	 -3.0
# Episode 266 result: 21 - 1 , epsilon: 0.875435973672018
# Average Reward	 -3.1
# Episode 267 result: 21 - 0 , epsilon: 0.874998255685182
# Average Reward	 -2.9
# Episode 268 result: 21 - 2 , epsilon: 0.8745607565573394
# Average Reward	 -2.7
# Episode 269 result: 21 - 0 , epsilon: 0.8741234761790608
# Average Reward	 -3.3
# Episode 270 result: 21 - 1 , epsilon: 0.8736864144409713
# Average Reward	 -2.9
# Episode 271 result: 21 - 1 , epsilon: 0.8732495712337509
# Average Reward	 -2.5
# Episode 272 result: 21 - 4 , epsilon: 0.872812946448134
# Average Reward	 -1.7
# Episode 273 result: 21 - 0 , epsilon: 0.87237653997491
# Average Reward	 -3.2
# Episode 274 result: 21 - 1 , epsilon: 0.8719403517049227
# Average Reward	 -2.5
# Episode 275 result: 21 - 0 , epsilon: 0.8715043815290702
# Average Reward	 -2.6
# Episode 276 result: 21 - 1 , epsilon: 0.8710686293383058
# Average Reward	 -2.7
# Episode 277 result: 21 - 0 , epsilon: 0.8706330950236366
# Average Reward	 -2.9
# Episode 278 result: 21 - 0 , epsilon: 0.8701977784761249
# Average Reward	 -3.0
# Episode 279 result: 21 - 1 , epsilon: 0.8697626795868868
# Average Reward	 -2.5
# Episode 280 result: 21 - 1 , epsilon: 0.8693277982470935
# Average Reward	 -3.0
# Episode 281 result: 21 - 1 , epsilon: 0.86889313434797
# Average Reward	 -2.6
# Episode 282 result: 21 - 1 , epsilon: 0.868458687780796
# Average Reward	 -2.6
# Episode 283 result: 21 - 4 , epsilon: 0.8680244584369057
# Average Reward	 -1.7
# Episode 284 result: 21 - 1 , epsilon: 0.8675904462076872
# Average Reward	 -2.7
# Episode 285 result: 21 - 2 , epsilon: 0.8671566509845835
# Average Reward	 -2.3
# Episode 286 result: 21 - 1 , epsilon: 0.8667230726590912
# Average Reward	 -2.3
# Episode 287 result: 21 - 1 , epsilon: 0.8662897111227618
# Average Reward	 -2.9
# Episode 288 result: 21 - 0 , epsilon: 0.8658565662672004
# Average Reward	 -3.2
# Episode 289 result: 21 - 2 , epsilon: 0.8654236379840669
# Average Reward	 -2.5
# Episode 290 result: 21 - 1 , epsilon: 0.8649909261650749
# Average Reward	 -2.9
# Episode 291 result: 21 - 0 , epsilon: 0.8645584307019923
# Average Reward	 -3.4
# Episode 292 result: 21 - 0 , epsilon: 0.8641261514866414
# Average Reward	 -3.5
# Episode 293 result: 21 - 1 , epsilon: 0.8636940884108981
# Average Reward	 -2.8
# Episode 294 result: 21 - 0 , epsilon: 0.8632622413666927
# Average Reward	 -2.4
# Episode 295 result: 21 - 0 , epsilon: 0.8628306102460094
# Average Reward	 -3.0
# Episode 296 result: 21 - 0 , epsilon: 0.8623991949408865
# Average Reward	 -3.0
# Episode 297 result: 21 - 0 , epsilon: 0.8619679953434161
# Average Reward	 -3.2
# Episode 298 result: 21 - 0 , epsilon: 0.8615370113457445
# Average Reward	 -3.3
# Episode 299 result: 21 - 1 , epsilon: 0.8611062428400716
# Average Reward	 -2.7
# Episode 300 result: 21 - 1 , epsilon: 0.8606756897186516
# Average Reward	 -3.0
# Episode 301 result: 21 - 0 , epsilon: 0.8602453518737924
# Average Reward	 -2.8
# Episode 302 result: 21 - 0 , epsilon: 0.8598152291978555
# Average Reward	 -3.1
# Episode 303 result: 21 - 1 , epsilon: 0.8593853215832566
# Average Reward	 -3.0
# Episode 304 result: 21 - 0 , epsilon: 0.858955628922465
# Average Reward	 -2.7
# Episode 305 result: 21 - 2 , epsilon: 0.8585261511080038
# Average Reward	 -2.7
# Episode 306 result: 21 - 1 , epsilon: 0.8580968880324499
# Average Reward	 -2.7
# Episode 307 result: 21 - 1 , epsilon: 0.8576678395884337
# Average Reward	 -2.9
# Episode 308 result: 21 - 0 , epsilon: 0.8572390056686395
# Average Reward	 -3.2
# Episode 309 result: 21 - 0 , epsilon: 0.8568103861658053
# Average Reward	 -3.2
# Episode 310 result: 21 - 0 , epsilon: 0.8563819809727224
# Average Reward	 -3.4
# Episode 311 result: 21 - 5 , epsilon: 0.855953789982236
# Average Reward	 -1.6
# Episode 312 result: 21 - 1 , epsilon: 0.8555258130872451
# Average Reward	 -2.8
# Episode 313 result: 21 - 0 , epsilon: 0.8550980501807014
# Average Reward	 -3.0
# Episode 314 result: 21 - 1 , epsilon: 0.8546705011556112
# Average Reward	 -2.8
# Episode 315 result: 21 - 0 , epsilon: 0.8542431659050334
# Average Reward	 -3.3
# Episode 316 result: 21 - 0 , epsilon: 0.8538160443220809
# Average Reward	 -2.8
# Episode 317 result: 21 - 0 , epsilon: 0.8533891362999199
# Average Reward	 -2.6
# Episode 318 result: 21 - 1 , epsilon: 0.85296244173177
# Average Reward	 -2.5
# Episode 319 result: 21 - 1 , epsilon: 0.8525359605109042
# Average Reward	 -2.6
# Episode 320 result: 21 - 3 , epsilon: 0.8521096925306487
# Average Reward	 -2.4
# Episode 321 result: 21 - 3 , epsilon: 0.8516836376843835
# Average Reward	 -2.2
# Episode 322 result: 21 - 1 , epsilon: 0.8512577958655413
# Average Reward	 -2.7
# Episode 323 result: 21 - 0 , epsilon: 0.8508321669676087
# Average Reward	 -2.3
# Episode 324 result: 21 - 0 , epsilon: 0.8504067508841249
# Average Reward	 -2.9
# Episode 325 result: 21 - 1 , epsilon: 0.8499815475086828
# Average Reward	 -2.8
# Episode 326 result: 21 - 1 , epsilon: 0.8495565567349286
# Average Reward	 -2.5
# Episode 327 result: 21 - 3 , epsilon: 0.8491317784565612
# Average Reward	 -2.0
# Episode 328 result: 21 - 0 , epsilon: 0.848707212567333
# Average Reward	 -2.5
# Episode 329 result: 21 - 2 , epsilon: 0.8482828589610493
# Average Reward	 -2.4
# Episode 330 result: 21 - 1 , epsilon: 0.8478587175315688
# Average Reward	 -2.2
# Episode 331 result: 21 - 2 , epsilon: 0.847434788172803
# Average Reward	 -2.8
# Episode 332 result: 21 - 0 , epsilon: 0.8470110707787167
# Average Reward	 -3.3
# Episode 333 result: 21 - 2 , epsilon: 0.8465875652433273
# Average Reward	 -2.3
# Episode 334 result: 21 - 1 , epsilon: 0.8461642714607057
# Average Reward	 -2.7
# Episode 335 result: 21 - 2 , epsilon: 0.8457411893249754
# Average Reward	 -2.2
# Episode 336 result: 21 - 1 , epsilon: 0.845318318730313
# Average Reward	 -2.4
# Episode 337 result: 21 - 2 , epsilon: 0.8448956595709479
# Average Reward	 -2.4
# Episode 338 result: 21 - 0 , epsilon: 0.8444732117411625
# Average Reward	 -2.7
# Episode 339 result: 21 - 3 , epsilon: 0.8440509751352919
# Average Reward	 -2.0
# Episode 340 result: 21 - 0 , epsilon: 0.8436289496477244
# Average Reward	 -2.8
# Episode 341 result: 21 - 1 , epsilon: 0.8432071351729006
# Average Reward	 -3.1
# Episode 342 result: 21 - 6 , epsilon: 0.8427855316053141
# Average Reward	 -1.4
# Episode 343 result: 21 - 3 , epsilon: 0.8423641388395116
# Average Reward	 -2.2
# Episode 344 result: 21 - 1 , epsilon: 0.8419429567700918
# Average Reward	 -2.0
# Episode 345 result: 21 - 0 , epsilon: 0.8415219852917069
# Average Reward	 -3.0
# Episode 346 result: 21 - 1 , epsilon: 0.841101224299061
# Average Reward	 -2.7
# Episode 347 result: 21 - 1 , epsilon: 0.8406806736869116
# Average Reward	 -2.5
# Episode 348 result: 21 - 1 , epsilon: 0.8402603333500681
# Average Reward	 -2.6
# Episode 349 result: 21 - 1 , epsilon: 0.8398402031833931
# Average Reward	 -2.2
# Episode 350 result: 21 - 1 , epsilon: 0.8394202830818015
# Average Reward	 -2.6
# Episode 351 result: 21 - 2 , epsilon: 0.8390005729402606
# Average Reward	 -2.4
# Episode 352 result: 21 - 0 , epsilon: 0.8385810726537906
# Average Reward	 -2.4
# Episode 353 result: 21 - 0 , epsilon: 0.8381617821174637
# Average Reward	 -3.3
# Episode 354 result: 21 - 3 , epsilon: 0.837742701226405
# Average Reward	 -2.4
# Episode 355 result: 21 - 1 , epsilon: 0.8373238298757919
# Average Reward	 -2.8
# Episode 356 result: 21 - 3 , epsilon: 0.836905167960854
# Average Reward	 -2.6
# Episode 357 result: 21 - 1 , epsilon: 0.8364867153768736
# Average Reward	 -2.7
# Episode 358 result: 21 - 1 , epsilon: 0.8360684720191852
# Average Reward	 -2.7
# Episode 359 result: 21 - 0 , epsilon: 0.8356504377831757
# Average Reward	 -3.1
# Episode 360 result: 21 - 2 , epsilon: 0.8352326125642842
# Average Reward	 -2.7
# Episode 361 result: 21 - 2 , epsilon: 0.834814996258002
# Average Reward	 -2.2
# Episode 362 result: 21 - 2 , epsilon: 0.8343975887598731
# Average Reward	 -2.5
# Episode 363 result: 21 - 1 , epsilon: 0.8339803899654932
# Average Reward	 -2.4
# Episode 364 result: 21 - 1 , epsilon: 0.8335633997705105
# Average Reward	 -2.1
# Episode 365 result: 21 - 1 , epsilon: 0.8331466180706253
# Average Reward	 -3.0
# Episode 366 result: 21 - 1 , epsilon: 0.8327300447615901
# Average Reward	 -2.5
# Episode 367 result: 21 - 0 , epsilon: 0.8323136797392092
# Average Reward	 -2.8
# Episode 368 result: 21 - 1 , epsilon: 0.8318975228993397
# Average Reward	 -2.7
# Episode 369 result: 21 - 3 , epsilon: 0.83148157413789
# Average Reward	 -2.2
# Episode 370 result: 21 - 1 , epsilon: 0.8310658333508212
# Average Reward	 -2.7
# Episode 371 result: 21 - 2 , epsilon: 0.8306503004341458
# Average Reward	 -2.0
# Episode 372 result: 21 - 1 , epsilon: 0.8302349752839288
# Average Reward	 -2.7
# Episode 373 result: 21 - 1 , epsilon: 0.8298198577962869
# Average Reward	 -2.5
# Episode 374 result: 21 - 0 , epsilon: 0.8294049478673888
# Average Reward	 -2.7
# Episode 375 result: 21 - 1 , epsilon: 0.8289902453934551
# Average Reward	 -2.9
# Episode 376 result: 21 - 0 , epsilon: 0.8285757502707585
# Average Reward	 -2.7
# Episode 377 result: 21 - 1 , epsilon: 0.8281614623956232
# Average Reward	 -2.7
# Episode 378 result: 21 - 1 , epsilon: 0.8277473816644253
# Average Reward	 -2.5
# Episode 379 result: 21 - 0 , epsilon: 0.8273335079735932
# Average Reward	 -2.9
# Episode 380 result: 21 - 2 , epsilon: 0.8269198412196064
# Average Reward	 -2.4
# Episode 381 result: 21 - 0 , epsilon: 0.8265063812989967
# Average Reward	 -2.7
# Episode 382 result: 21 - 2 , epsilon: 0.8260931281083472
# Average Reward	 -2.2
# Episode 383 result: 21 - 1 , epsilon: 0.8256800815442931
# Average Reward	 -2.5
# Episode 384 result: 21 - 3 , epsilon: 0.825267241503521
# Average Reward	 -2.2
# Episode 385 result: 21 - 0 , epsilon: 0.8248546078827693
# Average Reward	 -2.3
# Episode 386 result: 21 - 0 , epsilon: 0.8244421805788279
# Average Reward	 -3.2
# Episode 387 result: 21 - 2 , epsilon: 0.8240299594885385
# Average Reward	 -2.7
# Episode 388 result: 21 - 1 , epsilon: 0.8236179445087943
# Average Reward	 -2.5
# Episode 389 result: 21 - 2 , epsilon: 0.82320613553654
# Average Reward	 -2.4
# Episode 390 result: 21 - 2 , epsilon: 0.8227945324687718
# Average Reward	 -2.0
# Episode 391 result: 21 - 1 , epsilon: 0.8223831352025375
# Average Reward	 -2.5
# Episode 392 result: 21 - 1 , epsilon: 0.8219719436349362
# Average Reward	 -2.8
# Episode 393 result: 21 - 0 , epsilon: 0.8215609576631188
# Average Reward	 -3.0
# Episode 394 result: 21 - 1 , epsilon: 0.8211501771842873
# Average Reward	 -3.1
# Episode 395 result: 21 - 0 , epsilon: 0.8207396020956952
# Average Reward	 -3.3
# Episode 396 result: 21 - 0 , epsilon: 0.8203292322946474
# Average Reward	 -3.4
# Episode 397 result: 21 - 1 , epsilon: 0.8199190676785001
# Average Reward	 -3.0
# Episode 398 result: 21 - 1 , epsilon: 0.8195091081446609
# Average Reward	 -3.4
# Episode 399 result: 21 - 1 , epsilon: 0.8190993535905886
# Average Reward	 -3.1
# Episode 400 result: 21 - 1 , epsilon: 0.8186898039137933
# Average Reward	 -2.5
# Episode 401 result: 21 - 1 , epsilon: 0.8182804590118365
# Average Reward	 -3.0
# Episode 402 result: 21 - 0 , epsilon: 0.8178713187823307
# Average Reward	 -3.6
# Episode 403 result: 21 - 1 , epsilon: 0.8174623831229395
# Average Reward	 -2.7
# Episode 404 result: 21 - 1 , epsilon: 0.8170536519313781
# Average Reward	 -2.5
# Episode 405 result: 21 - 1 , epsilon: 0.8166451251054124
# Average Reward	 -2.2
# Episode 406 result: 21 - 2 , epsilon: 0.8162368025428598
# Average Reward	 -2.5
# Episode 407 result: 21 - 1 , epsilon: 0.8158286841415884
# Average Reward	 -2.7
# Episode 408 result: 21 - 0 , epsilon: 0.8154207697995176
# Average Reward	 -2.9
# Episode 409 result: 21 - 0 , epsilon: 0.8150130594146179
# Average Reward	 -3.1
# Episode 410 result: 21 - 3 , epsilon: 0.8146055528849107
# Average Reward	 -2.3
# Episode 411 result: 21 - 1 , epsilon: 0.8141982501084682
# Average Reward	 -2.5
# Episode 412 result: 21 - 1 , epsilon: 0.813791150983414
# Average Reward	 -3.0
# Episode 413 result: 21 - 1 , epsilon: 0.8133842554079224
# Average Reward	 -2.7
# Episode 414 result: 21 - 0 , epsilon: 0.8129775632802185
# Average Reward	 -2.5
# Episode 415 result: 21 - 4 , epsilon: 0.8125710744985785
# Average Reward	 -1.9
# Episode 416 result: 21 - 1 , epsilon: 0.8121647889613292
# Average Reward	 -2.8
# Episode 417 result: 21 - 0 , epsilon: 0.8117587065668486
# Average Reward	 -3.1
# Episode 418 result: 21 - 1 , epsilon: 0.8113528272135652
# Average Reward	 -3.0
# Episode 419 result: 21 - 0 , epsilon: 0.8109471507999584
# Average Reward	 -3.0
# Episode 420 result: 21 - 2 , epsilon: 0.8105416772245585
# Average Reward	 -3.0
# Episode 421 result: 21 - 1 , epsilon: 0.8101364063859463
# Average Reward	 -2.7
# Episode 422 result: 21 - 2 , epsilon: 0.8097313381827533
# Average Reward	 -2.2
# Episode 423 result: 21 - 2 , epsilon: 0.809326472513662
# Average Reward	 -2.2
# Episode 424 result: 21 - 0 , epsilon: 0.8089218092774052
# Average Reward	 -2.8
# Episode 425 result: 21 - 1 , epsilon: 0.8085173483727666
# Average Reward	 -2.6
# Episode 426 result: 21 - 0 , epsilon: 0.8081130896985802
# Average Reward	 -3.3
# Episode 427 result: 21 - 3 , epsilon: 0.807709033153731
# Average Reward	 -2.0
# Episode 428 result: 21 - 0 , epsilon: 0.8073051786371541
# Average Reward	 -2.9
# Episode 429 result: 21 - 1 , epsilon: 0.8069015260478356
# Average Reward	 -2.7
# Episode 430 result: 21 - 3 , epsilon: 0.8064980752848118
# Average Reward	 -1.8
# Episode 431 result: 21 - 0 , epsilon: 0.8060948262471694
# Average Reward	 -3.0
# Episode 432 result: 21 - 0 , epsilon: 0.8056917788340459
# Average Reward	 -3.0
# Episode 433 result: 21 - 2 , epsilon: 0.8052889329446289
# Average Reward	 -2.3
# Episode 434 result: 21 - 0 , epsilon: 0.8048862884781566
# Average Reward	 -3.0
# Episode 435 result: 21 - 3 , epsilon: 0.8044838453339176
# Average Reward	 -2.3
# Episode 436 result: 21 - 3 , epsilon: 0.8040816034112507
# Average Reward	 -1.9
# Episode 437 result: 21 - 1 , epsilon: 0.8036795626095451
# Average Reward	 -2.5
# Episode 438 result: 21 - 2 , epsilon: 0.8032777228282404
# Average Reward	 -2.7
# Episode 439 result: 21 - 1 , epsilon: 0.8028760839668263
# Average Reward	 -2.8
# Episode 440 result: 21 - 1 , epsilon: 0.8024746459248429
# Average Reward	 -2.6
# Episode 441 result: 21 - 1 , epsilon: 0.8020734086018805
# Average Reward	 -2.5
# Episode 442 result: 21 - 3 , epsilon: 0.8016723718975797
# Average Reward	 -2.1
# Episode 443 result: 21 - 1 , epsilon: 0.8012715357116309
# Average Reward	 -2.5
# Episode 444 result: 21 - 2 , epsilon: 0.8008708999437751
# Average Reward	 -2.3
# Episode 445 result: 21 - 0 , epsilon: 0.8004704644938032
# Average Reward	 -3.0
# Episode 446 result: 21 - 0 , epsilon: 0.8000702292615564
# Average Reward	 -3.2
# Episode 447 result: 21 - 1 , epsilon: 0.7996701941469256
# Average Reward	 -3.3
# Episode 448 result: 21 - 1 , epsilon: 0.7992703590498522
# Average Reward	 -2.5
# Episode 449 result: 21 - 1 , epsilon: 0.7988707238703274
# Average Reward	 -2.3
# Episode 450 result: 21 - 1 , epsilon: 0.7984712885083922
# Average Reward	 -2.5
# Episode 451 result: 21 - 4 , epsilon: 0.7980720528641381
# Average Reward	 -2.2
# Episode 452 result: 21 - 1 , epsilon: 0.7976730168377061
# Average Reward	 -3.1
# Episode 453 result: 21 - 0 , epsilon: 0.7972741803292873
# Average Reward	 -3.0
# Episode 454 result: 21 - 1 , epsilon: 0.7968755432391227
# Average Reward	 -2.8
# Episode 455 result: 21 - 0 , epsilon: 0.7964771054675032
# Average Reward	 -2.5
# Episode 456 result: 21 - 2 , epsilon: 0.7960788669147695
# Average Reward	 -2.3
# Episode 457 result: 21 - 0 , epsilon: 0.7956808274813121
# Average Reward	 -3.0
# Episode 458 result: 21 - 1 , epsilon: 0.7952829870675715
# Average Reward	 -2.8
# Episode 459 result: 21 - 3 , epsilon: 0.7948853455740378
# Average Reward	 -2.1
# Episode 460 result: 21 - 3 , epsilon: 0.7944879029012508
# Average Reward	 -2.0
# Episode 461 result: 21 - 0 , epsilon: 0.7940906589498002
# Average Reward	 -3.0
# Episode 462 result: 21 - 1 , epsilon: 0.7936936136203253
# Average Reward	 -2.5
# Episode 463 result: 21 - 0 , epsilon: 0.7932967668135152
# Average Reward	 -3.2
# Episode 464 result: 21 - 3 , epsilon: 0.7929001184301085
# Average Reward	 -2.6
# Episode 465 result: 21 - 1 , epsilon: 0.7925036683708935
# Average Reward	 -2.8
# Episode 466 result: 21 - 0 , epsilon: 0.7921074165367081
# Average Reward	 -2.6
# Episode 467 result: 21 - 1 , epsilon: 0.7917113628284398
# Average Reward	 -2.4
# Episode 468 result: 21 - 0 , epsilon: 0.7913155071470256
# Average Reward	 -3.1
# Episode 469 result: 21 - 2 , epsilon: 0.7909198493934522
# Average Reward	 -2.7
# Episode 470 result: 21 - 1 , epsilon: 0.7905243894687555
# Average Reward	 -2.6
# Episode 471 result: 21 - 3 , epsilon: 0.7901291272740211
# Average Reward	 -2.4
# Episode 472 result: 21 - 3 , epsilon: 0.7897340627103842
# Average Reward	 -2.0
# Episode 473 result: 21 - 2 , epsilon: 0.789339195679029
# Average Reward	 -2.3
# Episode 474 result: 21 - 1 , epsilon: 0.7889445260811895
# Average Reward	 -2.2
# Episode 475 result: 21 - 2 , epsilon: 0.788550053818149
# Average Reward	 -2.2
# Episode 476 result: 21 - 1 , epsilon: 0.78815577879124
# Average Reward	 -2.6
# Episode 477 result: 21 - 3 , epsilon: 0.7877617009018444
# Average Reward	 -2.6
# Episode 478 result: 21 - 3 , epsilon: 0.7873678200513935
# Average Reward	 -2.1
# Episode 479 result: 21 - 1 , epsilon: 0.7869741361413678
# Average Reward	 -2.6
# Episode 480 result: 21 - 1 , epsilon: 0.7865806490732972
# Average Reward	 -2.6
# Episode 481 result: 21 - 3 , epsilon: 0.7861873587487606
# Average Reward	 -2.3
# Episode 482 result: 21 - 1 , epsilon: 0.7857942650693862
# Average Reward	 -2.2
# Episode 483 result: 21 - 3 , epsilon: 0.7854013679368516
# Average Reward	 -2.2
# Episode 484 result: 21 - 4 , epsilon: 0.7850086672528832
# Average Reward	 -1.7
# Episode 485 result: 21 - 5 , epsilon: 0.7846161629192568
# Average Reward	 -1.5
# Episode 486 result: 21 - 0 , epsilon: 0.7842238548377972
# Average Reward	 -2.3
# Episode 487 result: 21 - 2 , epsilon: 0.7838317429103784
# Average Reward	 -2.7
# Episode 488 result: 21 - 0 , epsilon: 0.7834398270389232
# Average Reward	 -2.7
# Episode 489 result: 21 - 1 , epsilon: 0.7830481071254038
# Average Reward	 -2.9
# Episode 490 result: 21 - 1 , epsilon: 0.7826565830718412
# Average Reward	 -3.0
# Episode 491 result: 21 - 5 , epsilon: 0.7822652547803053
# Average Reward	 -1.5
# Episode 492 result: 21 - 4 , epsilon: 0.7818741221529152
# Average Reward	 -1.7
# Episode 493 result: 21 - 1 , epsilon: 0.7814831850918388
# Average Reward	 -2.7
# Episode 494 result: 21 - 3 , epsilon: 0.7810924434992929
# Average Reward	 -2.3
# Episode 495 result: 21 - 1 , epsilon: 0.7807018972775432
# Average Reward	 -3.0
# Episode 496 result: 21 - 2 , epsilon: 0.7803115463289045
# Average Reward	 -2.2
# Episode 497 result: 21 - 0 , epsilon: 0.7799213905557402
# Average Reward	 -3.6
# Episode 498 result: 21 - 3 , epsilon: 0.7795314298604623
# Average Reward	 -2.1
# Episode 499 result: 21 - 1 , epsilon: 0.7791416641455321
# Average Reward	 -2.6
# Episode 500 result: 21 - 1 , epsilon: 0.7787520933134594
# Average Reward	 -3.2
# Episode 501 result: 21 - 4 , epsilon: 0.7783627172668027
# Average Reward	 -1.8
# Episode 502 result: 21 - 2 , epsilon: 0.7779735359081693
# Average Reward	 -2.2
# Episode 503 result: 21 - 0 , epsilon: 0.7775845491402154
# Average Reward	 -2.8
# Episode 504 result: 21 - 2 , epsilon: 0.7771957568656452
# Average Reward	 -2.7
# Episode 505 result: 21 - 0 , epsilon: 0.7768071589872124
# Average Reward	 -3.2
# Episode 506 result: 21 - 3 , epsilon: 0.7764187554077189
# Average Reward	 -2.2
# Episode 507 result: 21 - 2 , epsilon: 0.7760305460300151
# Average Reward	 -2.5
# Episode 508 result: 21 - 0 , epsilon: 0.7756425307570001
# Average Reward	 -2.4
# Episode 509 result: 21 - 0 , epsilon: 0.7752547094916217
# Average Reward	 -3.3
# Episode 510 result: 21 - 1 , epsilon: 0.7748670821368759
# Average Reward	 -3.0
# Episode 511 result: 21 - 1 , epsilon: 0.7744796485958075
# Average Reward	 -2.8
# Episode 512 result: 21 - 4 , epsilon: 0.7740924087715096
# Average Reward	 -1.7
# Episode 513 result: 21 - 4 , epsilon: 0.773705362567124
# Average Reward	 -1.8
# Episode 514 result: 21 - 3 , epsilon: 0.7733185098858404
# Average Reward	 -1.9
# Episode 515 result: 21 - 1 , epsilon: 0.7729318506308975
# Average Reward	 -2.7
# Episode 516 result: 21 - 4 , epsilon: 0.7725453847055821
# Average Reward	 -1.8
# Episode 517 result: 21 - 2 , epsilon: 0.7721591120132294
# Average Reward	 -1.9
# Episode 518 result: 21 - 2 , epsilon: 0.7717730324572228
# Average Reward	 -2.2
# Episode 519 result: 21 - 1 , epsilon: 0.7713871459409942
# Average Reward	 -2.8
# Episode 520 result: 21 - 1 , epsilon: 0.7710014523680238
# Average Reward	 -3.1
# Episode 521 result: 21 - 4 , epsilon: 0.7706159516418398
# Average Reward	 -1.8
# Episode 522 result: 21 - 4 , epsilon: 0.7702306436660189
# Average Reward	 -1.9
# Episode 523 result: 21 - 1 , epsilon: 0.769845528344186
# Average Reward	 -2.5
# Episode 524 result: 21 - 3 , epsilon: 0.769460605580014
# Average Reward	 -2.1
# Episode 525 result: 21 - 2 , epsilon: 0.769075875277224
# Average Reward	 -2.5
# Episode 526 result: 21 - 1 , epsilon: 0.7686913373395854
# Average Reward	 -2.6
# Episode 527 result: 21 - 2 , epsilon: 0.7683069916709157
# Average Reward	 -2.6
# Episode 528 result: 21 - 3 , epsilon: 0.7679228381750802
# Average Reward	 -2.2
# Episode 529 result: 21 - 0 , epsilon: 0.7675388767559927
# Average Reward	 -2.1
# Episode 530 result: 21 - 2 , epsilon: 0.7671551073176147
# Average Reward	 -2.2
# Episode 531 result: 21 - 4 , epsilon: 0.766771529763956
# Average Reward	 -1.8
# Episode 532 result: 21 - 1 , epsilon: 0.7663881439990741
# Average Reward	 -2.3
# Episode 533 result: 21 - 4 , epsilon: 0.7660049499270746
# Average Reward	 -1.7
# Episode 534 result: 21 - 4 , epsilon: 0.7656219474521111
# Average Reward	 -1.8
# Episode 535 result: 21 - 1 , epsilon: 0.765239136478385
# Average Reward	 -2.7
# Episode 536 result: 21 - 1 , epsilon: 0.7648565169101459
# Average Reward	 -3.0
# Episode 537 result: 21 - 1 , epsilon: 0.7644740886516909
# Average Reward	 -2.8
# Episode 538 result: 21 - 2 , epsilon: 0.764091851607365
# Average Reward	 -2.6
# Episode 539 result: 21 - 2 , epsilon: 0.7637098056815614
# Average Reward	 -2.2
# Episode 540 result: 21 - 2 , epsilon: 0.7633279507787207
# Average Reward	 -2.5
# Episode 541 result: 21 - 3 , epsilon: 0.7629462868033314
# Average Reward	 -2.2
# Episode 542 result: 21 - 0 , epsilon: 0.7625648136599298
# Average Reward	 -2.8
# Episode 543 result: 21 - 3 , epsilon: 0.7621835312530998
# Average Reward	 -2.6
# Episode 544 result: 21 - 2 , epsilon: 0.7618024394874733
# Average Reward	 -2.3
# Episode 545 result: 21 - 1 , epsilon: 0.7614215382677296
# Average Reward	 -2.5
# Episode 546 result: 21 - 2 , epsilon: 0.7610408274985958
# Average Reward	 -2.3
# Episode 547 result: 21 - 4 , epsilon: 0.7606603070848466
# Average Reward	 -1.9
# Episode 548 result: 21 - 3 , epsilon: 0.7602799769313042
# Average Reward	 -1.9
# Episode 549 result: 21 - 2 , epsilon: 0.7598998369428386
# Average Reward	 -2.5
# Episode 550 result: 21 - 1 , epsilon: 0.7595198870243672
# Average Reward	 -2.8
# Episode 551 result: 21 - 1 , epsilon: 0.759140127080855
# Average Reward	 -3.4
# Episode 552 result: 21 - 2 , epsilon: 0.7587605570173147
# Average Reward	 -2.8
# Episode 553 result: 21 - 1 , epsilon: 0.758381176738806
# Average Reward	 -2.7
# Episode 554 result: 21 - 4 , epsilon: 0.7580019861504367
# Average Reward	 -2.0
# Episode 555 result: 21 - 3 , epsilon: 0.7576229851573615
# Average Reward	 -2.0
# Episode 556 result: 21 - 5 , epsilon: 0.7572441736647829
# Average Reward	 -1.8
# Episode 557 result: 21 - 3 , epsilon: 0.7568655515779505
# Average Reward	 -2.1
# Episode 558 result: 21 - 3 , epsilon: 0.7564871188021616
# Average Reward	 -2.3
# Episode 559 result: 21 - 2 , epsilon: 0.7561088752427605
# Average Reward	 -2.3
# Episode 560 result: 21 - 3 , epsilon: 0.7557308208051392
# Average Reward	 -2.4
# Episode 561 result: 21 - 3 , epsilon: 0.7553529553947367
# Average Reward	 -2.2
# Episode 562 result: 21 - 3 , epsilon: 0.7549752789170393
# Average Reward	 -1.9
# Episode 563 result: 21 - 1 , epsilon: 0.7545977912775809
# Average Reward	 -2.7
# Episode 564 result: 21 - 3 , epsilon: 0.7542204923819421
# Average Reward	 -2.1
# Episode 565 result: 21 - 3 , epsilon: 0.7538433821357512
# Average Reward	 -2.2
# Episode 566 result: 21 - 3 , epsilon: 0.7534664604446834
# Average Reward	 -2.1
# Episode 567 result: 21 - 1 , epsilon: 0.7530897272144611
# Average Reward	 -3.1
# Episode 568 result: 21 - 0 , epsilon: 0.7527131823508538
# Average Reward	 -2.8
# Episode 569 result: 21 - 7 , epsilon: 0.7523368257596785
# Average Reward	 -1.4
# Episode 570 result: 21 - 1 , epsilon: 0.7519606573467987
# Average Reward	 -2.7
# Episode 571 result: 21 - 3 , epsilon: 0.7515846770181254
# Average Reward	 -2.5
# ...
# Average Reward	 0.3
# Episode 3363 result: 21 - 13 , epsilon: 0.18601638547871746
# Average Reward	 -0.5
# Episode 3364 result: 20 - 21 , epsilon: 0.1859233772859781
# Average Reward	 -0.4
# Episode 3365 result: 21 - 18 , epsilon: 0.18583041559733512
# Average Reward	 -0.1
# Episode 3366 result: 21 - 20 , epsilon: 0.1857375003895365
# Average Reward	 -0.4
# Episode 3367 result: 21 - 18 , epsilon: 0.18564463163934172
# Average Reward	 -0.6
# Episode 3368 result: 21 - 11 , epsilon: 0.18555180932352205
# Average Reward	 -0.4
# Episode 3369 result: 21 - 15 , epsilon: 0.1854590334188603
# Average Reward	 -0.3
# Episode 3370 result: 21 - 15 , epsilon: 0.1853663039021509
# Average Reward	 -0.5
# Episode 3371 result: 21 - 13 , epsilon: 0.18527362075019982
# Average Reward	 -0.1
# Episode 3372 result: 21 - 11 , epsilon: 0.18518098393982474
# Average Reward	 -0.3
# Episode 3373 result: 21 - 15 , epsilon: 0.18508839344785483
# Average Reward	 -0.1
# Episode 3374 result: 21 - 6 , epsilon: 0.1849958492511309
# Average Reward	 -0.8
# Episode 3375 result: 21 - 16 , epsilon: 0.18490335132650534
# Average Reward	 -0.2
# Episode 3376 result: 21 - 11 , epsilon: 0.1848108996508421
# Average Reward	 -0.6
# Episode 3377 result: 18 - 21 , epsilon: 0.1847184942010167
# Average Reward	 0.6
# Episode 3378 result: 21 - 12 , epsilon: 0.1846261349539162
# Average Reward	 -0.1
# Episode 3379 result: 21 - 15 , epsilon: 0.18453382188643924
# Average Reward	 -0.5
# Episode 3380 result: 21 - 18 , epsilon: 0.18444155497549605
# Average Reward	 -0.6
# Episode 3381 result: 21 - 14 , epsilon: 0.1843493341980083
# Average Reward	 -0.9
# Episode 3382 result: 16 - 21 , epsilon: 0.18425715953090932
# Average Reward	 0.3
# Episode 3383 result: 21 - 13 , epsilon: 0.18416503095114387
# Average Reward	 -0.4
# Episode 3384 result: 21 - 19 , epsilon: 0.1840729484356683
# Average Reward	 0.5
# Episode 3385 result: 15 - 21 , epsilon: 0.18398091196145047
# Average Reward	 0.8
# Episode 3386 result: 20 - 21 , epsilon: 0.18388892150546976
# Average Reward	 0.1
# Episode 3387 result: 21 - 8 , epsilon: 0.18379697704471704
# Average Reward	 -0.8
# Episode 3388 result: 21 - 14 , epsilon: 0.1837050785561947
# Average Reward	 -0.5
# Episode 3389 result: 21 - 18 , epsilon: 0.1836132260169166
# Average Reward	 -0.3
# Episode 3390 result: 18 - 21 , epsilon: 0.18352141940390815
# Average Reward	 0.3
# Episode 3391 result: 18 - 21 , epsilon: 0.18342965869420622
# Average Reward	 -0.4
# Episode 3392 result: 21 - 20 , epsilon: 0.18333794386485913
# Average Reward	 0.0
# Episode 3393 result: 18 - 21 , epsilon: 0.1832462748929267
# Average Reward	 -0.3
# Episode 3394 result: 21 - 20 , epsilon: 0.18315465175548024
# Average Reward	 0.2
# Episode 3395 result: 21 - 13 , epsilon: 0.1830630744296025
# Average Reward	 -0.5
# Episode 3396 result: 21 - 13 , epsilon: 0.18297154289238773
# Average Reward	 -0.8
# Episode 3397 result: 21 - 16 , epsilon: 0.18288005712094155
# Average Reward	 0.0
# Episode 3398 result: 21 - 16 , epsilon: 0.1827886170923811
# Average Reward	 -0.5
# Episode 3399 result: 18 - 21 , epsilon: 0.1826972227838349
# Average Reward	 0.0
# Episode 3400 result: 12 - 21 , epsilon: 0.182605874172443
# Average Reward	 0.5
# Episode 3401 result: 21 - 20 , epsilon: 0.18251457123535678
# Average Reward	 0.0
# Episode 3402 result: 21 - 17 , epsilon: 0.18242331394973912
# Average Reward	 0.0
# Episode 3403 result: 20 - 21 , epsilon: 0.18233210229276425
# Average Reward	 -0.7
# Episode 3404 result: 21 - 18 , epsilon: 0.18224093624161788
# Average Reward	 -0.6
# Episode 3405 result: 21 - 13 , epsilon: 0.1821498157734971
# Average Reward	 -1.0
# Episode 3406 result: 18 - 21 , epsilon: 0.18205874086561036
# Average Reward	 0.1
# Episode 3407 result: 17 - 21 , epsilon: 0.18196771149517754
# Average Reward	 0.4
# Episode 3408 result: 17 - 21 , epsilon: 0.18187672763942997
# Average Reward	 -0.1
# Episode 3409 result: 21 - 14 , epsilon: 0.18178578927561026
# Average Reward	 -0.4
# Episode 3410 result: 21 - 18 , epsilon: 0.18169489638097247
# Average Reward	 0.0
# Episode 3411 result: 21 - 15 , epsilon: 0.181604048932782
# Average Reward	 0.4
# Episode 3412 result: 21 - 18 , epsilon: 0.1815132469083156
# Average Reward	 0.1
# Episode 3413 result: 21 - 11 , epsilon: 0.18142249028486146
# Average Reward	 -0.5
# Episode 3414 result: 21 - 20 , epsilon: 0.18133177903971906
# Average Reward	 -0.1
# Episode 3415 result: 21 - 16 , epsilon: 0.1812411131501992
# Average Reward	 0.1
# Episode 3416 result: 21 - 19 , epsilon: 0.18115049259362412
# Average Reward	 -0.1
# Episode 3417 result: 21 - 17 , epsilon: 0.1810599173473273
# Average Reward	 0.2
# Episode 3418 result: 21 - 20 , epsilon: 0.18096938738865365
# Average Reward	 -0.7
# Episode 3419 result: 21 - 14 , epsilon: 0.18087890269495935
# Average Reward	 0.0
# Episode 3420 result: 21 - 16 , epsilon: 0.18078846324361186
# Average Reward	 -0.3
# Episode 3421 result: 21 - 16 , epsilon: 0.18069806901199006
# Average Reward	 -0.5
# Episode 3422 result: 21 - 18 , epsilon: 0.1806077199774841
# Average Reward	 0.3
# Episode 3423 result: 21 - 18 , epsilon: 0.18051741611749536
# Average Reward	 -0.1
# Episode 3424 result: 10 - 21 , epsilon: 0.18042715740943663
# Average Reward	 0.8
# Episode 3425 result: 16 - 21 , epsilon: 0.1803369438307319
# Average Reward	 -0.2
# Episode 3426 result: 21 - 13 , epsilon: 0.18024677535881656
# Average Reward	 -0.3
# Episode 3427 result: 21 - 16 , epsilon: 0.18015665197113714
# Average Reward	 -0.3
# Episode 3428 result: 21 - 16 , epsilon: 0.1800665736451516
# Average Reward	 0.0
# Episode 3429 result: 15 - 21 , epsilon: 0.17997654035832902
# Average Reward	 0.0
# Episode 3430 result: 21 - 19 , epsilon: 0.17988655208814988
# Average Reward	 -0.1
# Episode 3431 result: 18 - 21 , epsilon: 0.1797966088121058
# Average Reward	 0.2
# Episode 3432 result: 20 - 21 , epsilon: 0.17970671050769976
# Average Reward	 0.1
# Episode 3433 result: 21 - 18 , epsilon: 0.17961685715244594
# Average Reward	 0.0
# Episode 3434 result: 21 - 11 , epsilon: 0.1795270487238697
# Average Reward	 -0.3
# Episode 3435 result: 21 - 15 , epsilon: 0.17943728519950777
# Average Reward	 -0.5
# Episode 3436 result: 21 - 7 , epsilon: 0.17934756655690803
# Average Reward	 -0.2
# Episode 3437 result: 21 - 7 , epsilon: 0.1792578927736296
# Average Reward	 -0.6
# Episode 3438 result: 21 - 6 , epsilon: 0.1791682638272428
# Average Reward	 -0.8
# Episode 3439 result: 21 - 9 , epsilon: 0.17907867969532917
# Average Reward	 -0.8
# Episode 3440 result: 21 - 14 , epsilon: 0.17898914035548152
# Average Reward	 -0.2
# Episode 3441 result: 21 - 14 , epsilon: 0.1788996457853038
# Average Reward	 -0.3
# Episode 3442 result: 21 - 17 , epsilon: 0.17881019596241116
# Average Reward	 0.0
# Episode 3443 result: 21 - 19 , epsilon: 0.17872079086442996
# Average Reward	 -0.2
# Episode 3444 result: 21 - 14 , epsilon: 0.17863143046899777
# Average Reward	 -0.2
# Episode 3445 result: 20 - 21 , epsilon: 0.17854211475376328
# Average Reward	 -0.1
# Episode 3446 result: 21 - 7 , epsilon: 0.1784528436963864
# Average Reward	 -0.6
# Episode 3447 result: 21 - 11 , epsilon: 0.1783636172745382
# Average Reward	 -0.3
# Episode 3448 result: 21 - 19 , epsilon: 0.17827443546590094
# Average Reward	 -0.1
# Episode 3449 result: 21 - 13 , epsilon: 0.178185298248168
# Average Reward	 -0.1
# Episode 3450 result: 21 - 12 , epsilon: 0.17809620559904393
# Average Reward	 -0.6
# Episode 3451 result: 21 - 17 , epsilon: 0.17800715749624443
# Average Reward	 0.1
# Episode 3452 result: 21 - 14 , epsilon: 0.1779181539174963
# Average Reward	 -0.9
# Episode 3453 result: 14 - 21 , epsilon: 0.17782919484053758
# Average Reward	 0.7
# Episode 3454 result: 21 - 16 , epsilon: 0.1777402802431173
# Average Reward	 -0.3
# Episode 3455 result: 21 - 13 , epsilon: 0.17765141010299576
# Average Reward	 -0.5
# Episode 3456 result: 21 - 15 , epsilon: 0.17756258439794428
# Average Reward	 -0.2
# Episode 3457 result: 18 - 21 , epsilon: 0.17747380310574531
# Average Reward	 -0.3
# Episode 3458 result: 21 - 15 , epsilon: 0.17738506620419245
# Average Reward	 -0.7
# Episode 3459 result: 21 - 7 , epsilon: 0.17729637367109036
# Average Reward	 -0.3
# Episode 3460 result: 21 - 16 , epsilon: 0.17720772548425484
# Average Reward	 -0.5
# Episode 3461 result: 21 - 19 , epsilon: 0.17711912162151272
# Average Reward	 0.0
# Episode 3462 result: 21 - 12 , epsilon: 0.17703056206070197
# Average Reward	 -0.5
# Episode 3463 result: 12 - 21 , epsilon: 0.17694204677967162
# Average Reward	 0.5
# Episode 3464 result: 21 - 11 , epsilon: 0.1768535757562818
# Average Reward	 -0.3
# Episode 3465 result: 21 - 16 , epsilon: 0.17676514896840367
# Average Reward	 -0.1
# Episode 3466 result: 21 - 20 , epsilon: 0.17667676639391947
# Average Reward	 -0.1
# Episode 3467 result: 21 - 13 , epsilon: 0.17658842801072253
# Average Reward	 -0.4
# Episode 3468 result: 21 - 18 , epsilon: 0.17650013379671717
# Average Reward	 0.2
# Episode 3469 result: 21 - 10 , epsilon: 0.17641188372981884
# Average Reward	 -0.8
# Episode 3470 result: 21 - 15 , epsilon: 0.17632367778795394
# Average Reward	 -0.4
# Episode 3471 result: 17 - 21 , epsilon: 0.17623551594905995
# Average Reward	 0.3
# Episode 3472 result: 21 - 8 , epsilon: 0.17614739819108544
# Average Reward	 -0.7
# Episode 3473 result: 21 - 12 , epsilon: 0.1760593244919899
# Average Reward	 0.0
# Episode 3474 result: 21 - 19 , epsilon: 0.1759712948297439
# Average Reward	 0.1
# Episode 3475 result: 20 - 21 , epsilon: 0.17588330918232906
# Average Reward	 0.3
# Episode 3476 result: 21 - 14 , epsilon: 0.1757953675277379
# Average Reward	 -0.7
# Episode 3477 result: 21 - 16 , epsilon: 0.17570746984397403
# Average Reward	 -0.7
# Episode 3478 result: 21 - 20 , epsilon: 0.17561961610905205
# Average Reward	 -0.3
# Episode 3479 result: 21 - 15 , epsilon: 0.17553180630099754
# Average Reward	 -0.4
# Episode 3480 result: 21 - 10 , epsilon: 0.17544404039784706
# Average Reward	 -0.2
# Episode 3481 result: 21 - 14 , epsilon: 0.17535631837764815
# Average Reward	 -0.2
# Episode 3482 result: 14 - 21 , epsilon: 0.17526864021845934
# Average Reward	 0.1
# Episode 3483 result: 21 - 15 , epsilon: 0.17518100589835012
# Average Reward	 -0.1
# Episode 3484 result: 15 - 21 , epsilon: 0.17509341539540094
# Average Reward	 0.4
# Episode 3485 result: 21 - 16 , epsilon: 0.17500586868770326
# Average Reward	 -0.3
# Episode 3486 result: 19 - 21 , epsilon: 0.17491836575335942
# Average Reward	 0.0
# Episode 3487 result: 21 - 13 , epsilon: 0.17483090657048275
# Average Reward	 -0.8
# Episode 3488 result: 21 - 14 , epsilon: 0.1747434911171975
# Average Reward	 -0.1
# Episode 3489 result: 17 - 21 , epsilon: 0.1746561193716389
# Average Reward	 0.1
# Episode 3490 result: 21 - 18 , epsilon: 0.1745687913119531
# Average Reward	 -0.2
# Episode 3491 result: 18 - 21 , epsilon: 0.17448150691629716
# Average Reward	 0.3
# Episode 3492 result: 19 - 21 , epsilon: 0.174394266162839
# Average Reward	 0.4
# Episode 3493 result: 21 - 20 , epsilon: 0.1743070690297576
# Average Reward	 -0.6
# Episode 3494 result: 21 - 9 , epsilon: 0.17421991549524274
# Average Reward	 -0.6
# Episode 3495 result: 18 - 21 , epsilon: 0.1741328055374951
# Average Reward	 -0.2
# Episode 3496 result: 21 - 9 , epsilon: 0.17404573913472637
# Average Reward	 -0.7
# Episode 3497 result: 21 - 17 , epsilon: 0.17395871626515902
# Average Reward	 -0.6
# Episode 3498 result: 10 - 21 , epsilon: 0.17387173690702645
# Average Reward	 0.5
# Episode 3499 result: 21 - 9 , epsilon: 0.17378480103857294
# Average Reward	 -1.0
# Episode 3500 result: 16 - 21 , epsilon: 0.17369790863805368
# Average Reward	 0.6
# Episode 3501 result: 21 - 10 , epsilon: 0.17361105968373466
# Average Reward	 -0.8
# Episode 3502 result: 21 - 12 , epsilon: 0.1735242541538928
# Average Reward	 -0.8
# Episode 3503 result: 21 - 18 , epsilon: 0.17343749202681585
# Average Reward	 -0.1
# Episode 3504 result: 21 - 20 , epsilon: 0.17335077328080245
# Average Reward	 -0.2
# Episode 3505 result: 15 - 21 , epsilon: 0.17326409789416208
# Average Reward	 0.1
# Episode 3506 result: 18 - 21 , epsilon: 0.173177465845215
# Average Reward	 0.1
# Episode 3507 result: 21 - 10 , epsilon: 0.1730908771122924
# Average Reward	 -1.0
# Episode 3508 result: 19 - 21 , epsilon: 0.17300433167373627
# Average Reward	 0.4
# Episode 3509 result: 20 - 21 , epsilon: 0.1729178295078994
# Average Reward	 -0.5
# Episode 3510 result: 21 - 10 , epsilon: 0.17283137059314546
# Average Reward	 -1.0
# Episode 3511 result: 21 - 9 , epsilon: 0.1727449549078489
# Average Reward	 -0.6
# Episode 3512 result: 21 - 19 , epsilon: 0.17265858243039497
# Average Reward	 0.1
# Episode 3513 result: 21 - 17 , epsilon: 0.1725722531391798
# Average Reward	 0.4
# Episode 3514 result: 21 - 15 , epsilon: 0.1724859670126102
# Average Reward	 -0.2
# Episode 3515 result: 21 - 19 , epsilon: 0.17239972402910392
# Average Reward	 0.2
# Episode 3516 result: 21 - 15 , epsilon: 0.1723135241670894
# Average Reward	 -0.7
# Episode 3517 result: 21 - 17 , epsilon: 0.17222736740500585
# Average Reward	 -0.5
# Episode 3518 result: 21 - 15 , epsilon: 0.17214125372130334
# Average Reward	 -0.1
# Episode 3519 result: 12 - 21 , epsilon: 0.1720551830944427
# Average Reward	 1.0
# Episode 3520 result: 13 - 21 , epsilon: 0.1719691555028955
# Average Reward	 0.7
# Episode 3521 result: 21 - 11 , epsilon: 0.17188317092514405
# Average Reward	 -1.0
# Episode 3522 result: 21 - 17 , epsilon: 0.1717972293396815
# Average Reward	 0.2
# Episode 3523 result: 21 - 20 , epsilon: 0.17171133072501166
# Average Reward	 -0.3
# Episode 3524 result: 19 - 21 , epsilon: 0.17162547505964917
# Average Reward	 0.7
# Episode 3525 result: 21 - 20 , epsilon: 0.17153966232211937
# Average Reward	 0.5
# Episode 3526 result: 21 - 17 , epsilon: 0.1714538924909583
# Average Reward	 -0.4
# Episode 3527 result: 9 - 21 , epsilon: 0.17136816554471285
# Average Reward	 0.7
# Episode 3528 result: 12 - 21 , epsilon: 0.1712824814619405
# Average Reward	 0.0
# Episode 3529 result: 20 - 21 , epsilon: 0.17119684022120954
# Average Reward	 0.3
# Episode 3530 result: 21 - 18 , epsilon: 0.17111124180109893
# Average Reward	 -0.5
# Episode 3531 result: 21 - 20 , epsilon: 0.1710256861801984
# Average Reward	 -0.3
# Episode 3532 result: 14 - 21 , epsilon: 0.17094017333710831
# Average Reward	 0.2
# Episode 3533 result: 11 - 21 , epsilon: 0.17085470325043975
# Average Reward	 0.4
# Episode 3534 result: 11 - 21 , epsilon: 0.17076927589881455
# Average Reward	 0.5
# Episode 3535 result: 17 - 21 , epsilon: 0.17068389126086514
# Average Reward	 0.5
# Episode 3536 result: 21 - 13 , epsilon: 0.17059854931523472
# Average Reward	 -0.6
# Episode 3537 result: 14 - 21 , epsilon: 0.17051325004057713
# Average Reward	 0.5
# Episode 3538 result: 21 - 10 , epsilon: 0.17042799341555684
# Average Reward	 -0.2
# Episode 3539 result: 21 - 15 , epsilon: 0.17034277941884907
# Average Reward	 -0.3
# Episode 3540 result: 21 - 12 , epsilon: 0.17025760802913967
# Average Reward	 -0.4
# Episode 3541 result: 21 - 10 , epsilon: 0.1701724792251251
# Average Reward	 -0.6
# Episode 3542 result: 21 - 7 , epsilon: 0.17008739298551254
# Average Reward	 -0.2
# Episode 3543 result: 21 - 18 , epsilon: 0.1700023492890198
# Average Reward	 -0.1
# Episode 3544 result: 21 - 12 , epsilon: 0.16991734811437528
# Average Reward	 -0.3
# Episode 3545 result: 20 - 21 , epsilon: 0.16983238944031812
# Average Reward	 -0.5
# Episode 3546 result: 21 - 20 , epsilon: 0.16974747324559797
# Average Reward	 0.1
# Episode 3547 result: 21 - 20 , epsilon: 0.16966259950897516
# Average Reward	 -0.4
# Episode 3548 result: 21 - 18 , epsilon: 0.1695777682092207
# Average Reward	 -0.8
# Episode 3549 result: 21 - 13 , epsilon: 0.1694929793251161
# Average Reward	 -0.4
# Episode 3550 result: 16 - 21 , epsilon: 0.16940823283545356
# Average Reward	 0.3
# Episode 3551 result: 21 - 14 , epsilon: 0.16932352871903583
# Average Reward	 -0.4
# Episode 3552 result: 21 - 20 , epsilon: 0.16923886695467633
# Average Reward	 -0.3
# Episode 3553 result: 10 - 21 , epsilon: 0.16915424752119898
# Average Reward	 0.3
# Episode 3554 result: 14 - 21 , epsilon: 0.1690696703974384
# Average Reward	 0.3
# Episode 3555 result: 17 - 21 , epsilon: 0.16898513556223968
# Average Reward	 0.1
# Episode 3556 result: 21 - 15 , epsilon: 0.1689006429944586
# Average Reward	 -0.2
# Episode 3557 result: 21 - 19 , epsilon: 0.16881619267296136
# Average Reward	 0.1
# Episode 3558 result: 18 - 21 , epsilon: 0.16873178457662488
# Average Reward	 -0.5
# Episode 3559 result: 21 - 12 , epsilon: 0.16864741868433658
# Average Reward	 0.0
# Episode 3560 result: 18 - 21 , epsilon: 0.16856309497499442
# Average Reward	 0.0
# Episode 3561 result: 21 - 19 , epsilon: 0.16847881342750695
# Average Reward	 0.1
